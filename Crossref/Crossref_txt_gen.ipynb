# %%
import json
import os

# %%
f = open('/Users/maria/Desktop/Resilience_Lit_Review/crossref_has_abstract.json')
data = json.load(f)

# %%
len(data)
# Out:
# 25134

# %%
data[12]
# Out:
# {'indexed': {'date-parts': [[2024, 1, 25]],
#   'date-time': '2024-01-25T02:24:28Z',
#   'timestamp': 1706149468913},
#  'reference-count': 55,
#  'publisher': 'Wiley',
#  'issue': '3',
#  'license': [{'start': {'date-parts': [[2002, 4, 15]],
#     'date-time': '2002-04-15T00:00:00Z',
#     'timestamp': 1018828800000},
#    'content-version': 'vor',
#    'delay-in-days': 45,
#    'URL': 'http://onlinelibrary.wiley.com/termsAndConditions#vor'}],
#  'content-domain': {'domain': [], 'crossmark-restriction': False},
#  'short-container-title': ['J Clin Psychol'],
#  'published-print': {'date-parts': [[2002, 3]]},
# ...

# %%
directory = "/Users/maria/Desktop"
os.chdir(directory)

# %%
i = 0
filename_stem = "crossref_abstract_"
for record in data:
    abstract = record['abstract']
    filename = filename_stem+str(i)+'.txt'
    f = open(filename, "w")
    f.write(abstract)
    f.close()
    i = i+1
