# %%
import json
import csv

# %%
f = open('D:\\crossref_has_abstract_cleaned.json')
json_data = json.load(f)

# %%
json_data[0]['published-online']['date-parts'][0][0]
# Out:
# 2021

# %%
json_data[0]
# Out:
# {'indexed': {'date-parts': [[2024, 1, 26]],
#   'date-time': '2024-01-26T08:18:06Z',
#   'timestamp': 1706257086636},
#  'reference-count': 88,
#  'publisher': 'SAGE Publications',
#  'issue': '8',
#  'license': [{'start': {'date-parts': [[2021, 7, 2]],
#     'date-time': '2021-07-02T00:00:00Z',
#     'timestamp': 1625184000000},
#    'content-version': 'unspecified',
#    'delay-in-days': 0,
#    'URL': 'https://creativecommons.org/licenses/by-nc/4.0/'}],
#  'content-domain': {'domain': ['journals.sagepub.com'],
#   'crossmark-restriction': True},
#  'short-container-title': ['Youth &amp; Society'],
#  'published-print': {'date-parts': [[2022, 11]]},
# ...

# %%
for i in range(len(data)):
    year = json_data[i]

# %%
json_data[0]['published-online']['date-parts'][0][0]
# Out:
# 2021
